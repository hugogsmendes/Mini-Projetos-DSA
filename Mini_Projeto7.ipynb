# %% [markdown]
# <a href="https://colab.research.google.com/github/hugogsmendes/Mini-Projetos-DSA/blob/main/Mini_Projeto7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mini-Projeto 7**
#
# ## Deep Learning com PyTorch para Classificação de Imagens

# %% [markdown]
# ### 1. Instalação e Importação dos Pacotes
